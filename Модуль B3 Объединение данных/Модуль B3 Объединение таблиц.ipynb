# %%
import pandas as pd
rating = pd.read_csv('rating.csv')
display(rating.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100836 entries, 0 to 100835
# Data columns (total 4 columns):
# userId       100836 non-null int64
# movieId      100836 non-null int64
# rating       100836 non-null float64
# timestamp    100836 non-null int64
# dtypes: float64(1), int64(3)
# memory usage: 3.1 MB
# None

# %%
import pandas as pd
movies = pd.read_csv('movies.csv')
display(movies.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9742 entries, 0 to 9741
# Data columns (total 3 columns):
# movieId    9742 non-null object
# title      7661 non-null object
# genres     7661 non-null object
# dtypes: object(3)
# memory usage: 228.5+ KB
# None

# %% [markdown]
# Задание 1
# 1 point possible (graded)
# Скачайте файлы ratings.csv и movies.csv из предыдущего шага. Давайте повторим основные методы получения информации о датасете, которые мы изучали в модуле 1 "Общее знакомство с библиотекой Pandas".
# Сколько строк в файле рейтингов, не считая строки заголовка (подсказка: количество непустых значений соответствует количеству строк)?

# %%
display(rating.describe())
display(movies.describe())
# Out:
#               userId        movieId         rating     timestamp
# count  100836.000000  100836.000000  100836.000000  1.008360e+05
# mean      326.127564   19435.295718       3.501557  1.205946e+09
# std       182.618491   35530.987199       1.042529  2.162610e+08
# min         1.000000       1.000000       0.500000  8.281246e+08
# 25%       177.000000    1199.000000       3.000000  1.019124e+09
# 50%       325.000000    2991.000000       3.500000  1.186087e+09
# 75%       477.000000    8122.000000       4.000000  1.435994e+09
# max       610.000000  193609.000000       5.000000  1.537799e+09
#        movieId                                   title  genres
# count     9742                                    7661    7661
# unique    9742                                    7656     840
# top        201  Confessions of a Dangerous Mind (2002)  Comedy
# freq         1                                       2     794

# %%
display(movies.head())
# Out:
#   movieId                               title  \
# 0       1                    Toy Story (1995)
# 1       2                      Jumanji (1995)
# 2       3             Grumpier Old Men (1995)
# 3       4            Waiting to Exhale (1995)
# 4       5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
display(rating.head())
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
items_dict = {

    'item_id': [417283, 849734, 132223, 573943, 19475, 3294095, 382043, 302948, 100132, 312394], 

    'vendor': ['Samsung', 'LG', 'Apple', 'Apple', 'LG', 'Apple', 'Samsung', 'Samsung', 'LG', 'ZTE'],

    'stock_count': [54, 33, 122, 18, 102, 43, 77, 143, 60, 19]

}

# %%
purchase_log = {

    'purchase_id': [101, 101, 101, 112, 121, 145, 145, 145, 145, 221],

    'item_id': [417283, 849734, 132223, 573943, 19475, 3294095, 382043, 302948, 103845, 100132], 

    'price': [13900, 5330, 38200, 49990, 9890, 33000, 67500, 34500, 89900, 11400]

}

# %%
items_df = pd.DataFrame(items_dict)
purchase_df = pd.DataFrame(purchase_log)

# %% [markdown]
# Задание 1
# 1 point possible (graded)
# Объедините получившиеся датафреймы по столбцу item_id с типом outer.
# Определите, модель с каким item_id есть в статистике продаж purchase_df, но не учтена на складе (подсказка: подумайте, какой датафрейм должен быть "левым", а какой "правым", чтобы получить необходимые данные). Введите ответ в виде целого числа.

# %%
merge_df=purchase_df.merge(items_df, how = 'outer', on = 'item_id')
display(merge_df)
# Out:
#     purchase_id  item_id    price   vendor  stock_count
# 0         101.0   417283  13900.0  Samsung         54.0
# 1         101.0   849734   5330.0       LG         33.0
# 2         101.0   132223  38200.0    Apple        122.0
# 3         112.0   573943  49990.0    Apple         18.0
# 4         121.0    19475   9890.0       LG        102.0
# 5         145.0  3294095  33000.0    Apple         43.0
# 6         145.0   382043  67500.0  Samsung         77.0
# 7         145.0   302948  34500.0  Samsung        143.0
# 8         145.0   103845  89900.0      NaN          NaN
# 9         221.0   100132  11400.0       LG         60.0
# 10          NaN   312394      NaN      ZTE         19.0

# %% [markdown]
# Задание 3
# 1/1 point (graded)
# Сформируйте датафрейм merged, в котором в результате объединения purchase_df и items_df останутся модели, которые учтены на складе и имели продажи. Сколько всего таких моделей?

# %%
merge_df=purchase_df.merge(items_df, how = 'left', on = 'item_id')
display(merge_df)
# Out:
#    purchase_id  item_id  price   vendor  stock_count
# 0          101   417283  13900  Samsung         54.0
# 1          101   849734   5330       LG         33.0
# 2          101   132223  38200    Apple        122.0
# 3          112   573943  49990    Apple         18.0
# 4          121    19475   9890       LG        102.0
# 5          145  3294095  33000    Apple         43.0
# 6          145   382043  67500  Samsung         77.0
# 7          145   302948  34500  Samsung        143.0
# 8          145   103845  89900      NaN          NaN
# 9          221   100132  11400       LG         60.0

# %% [markdown]
# Задание 4
# 1 point possible (graded)
# Посчитайте объем выручки для каждой модели, которую можно получить, распродав все остатки на складе. Модель с каким item_id имеет максимальное значение выручки после распродажи остатков? Ответ дайте в виде целого числа.
# Примечание: перемножение столбцов датафрейма можно производить разными способами, но самый простой - перемножение "в лоб" вида df['col1'] = df['col2'] * df['col3']. Для присоединения новых данных к датафрейму тоже можно использовать различные методы, включая функцию .append(), которая позволяет присоединять к датафрейму другой датафрейм, серии или словари.

# %%
merge_df[summ_revenue]=merge_df[stock_count]*merge_df[price]
#display(merge_df.describe())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-3170b490bfc6> in <module>
# ----> 1 merge_df[summ_revenue]=merge_df[stock_count]*merge_df[price]
#       2 #display(merge_df.describe())
#
# NameError: name 'stock_count' is not defined

# %%
sell_merge_df=merge_df.append(merge_df[stock_count]*merge_df[price])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-a9d377a02196> in <module>
# ----> 1 sell_merge_df=merge_df.append(merge_df[stock_count]*merge_df[price])
#
# NameError: name 'stock_count' is not defined

# %%
import os
#Для получения списка файлов воспользуемся методом listdir. В качестве аргумента указываем папку 'data':
files = os.listdir('data')
files
# Out:
# ['ratings_1.txt',
#  'ratings_10.txt',
#  'ratings_2.txt',
#  'ratings_3.txt',
#  'ratings_4.txt',
#  'ratings_5.txt',
#  'ratings_6.txt',
#  'ratings_7.txt',
#  'ratings_8.txt',
#  'ratings_9.txt']

# %% [markdown]
# 1 point possible (graded)
# После чтения папки список файлов оказался следующим:
# files = ['setup.py', 'ratings.txt', 'stock_stats.txt', 'movies.txt', 'run.sh', 'game_of_thrones.mov']
# Создайте на основе списка files новый список data, в который поместите только файлы, содержащие в названии "txt".

# %%
data=[]
files = ['setup.py', 'ratings.txt', 'stock_stats.txt', 'movies.txt', 'run.sh', 'game_of_thrones.mov']
for item in files:
    if item.find('.txt')>0 :
        data.append(item)
    else:
        continue
print (data)
# Out:
# ['ratings.txt', 'stock_stats.txt', 'movies.txt']

# %%
for root, dirs, files in os.walk('data'):
    print(root, dirs, files)
# Out:
# data [] ['ratings_1.txt', 'ratings_10.txt', 'ratings_2.txt', 'ratings_3.txt', 'ratings_4.txt', 'ratings_5.txt', 'ratings_6.txt', 'ratings_7.txt', 'ratings_8.txt', 'ratings_9.txt']

# %% [markdown]
# На прошлом шаге мы получили список файлов в папке. Теперь нам необходимо содержимое этих файлов, собрать в одном датафрейме. Это можно сделать используя метод concatenate.

# %%
data = pd.DataFrame(columns = ['userId', 'movieId', 'rating', 'timestamp'])
temp = pd.read_csv( os.path.join('data', filename), names = ['userId', 'movieId', 'rating', 'timestamp'] )
data = pd.concat([data, temp])

# %% [markdown]
# Напишите цикл, который собирает содержимое файлов папки data в единый датафрейм data.
# Сколько строк в датафрейме data?

# %%
import pandas as pd
rating = pd.read_csv('data/ratings_1.txt')
display(rating.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9998 entries, 0 to 9997
# Data columns (total 4 columns):
# 1             9998 non-null int64
# 31            9998 non-null int64
# 2.5           9998 non-null float64
# 1260759144    9998 non-null int64
# dtypes: float64(1), int64(3)
# memory usage: 312.6 KB
# None

# %%
data = pd.DataFrame(columns = ['userId', 'movieId', 'rating', 'timestamp'])
for root, dirs, files in os.walk('data'):
    for item in files:
        temp = pd.read_csv( os.path.join('data', item), names = ['userId', 'movieId', 'rating', 'timestamp'] )
        data = pd.concat([data, temp])
    else:
        display(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100004 entries, 0 to 9999
# Data columns (total 4 columns):
# userId       100004 non-null object
# movieId      100004 non-null object
# rating       100004 non-null float64
# timestamp    100004 non-null object
# dtypes: float64(1), object(3)
# memory usage: 3.8+ MB
# None

# %% [markdown]
# Сколько раз была выставлена низшая оценка 0.5 в наших рейтингах? Используйте файл ratings.csv.

# %%
import pandas as pd
rating = pd.read_csv('rating.csv')
display(rating.loc[rating.rating==0.5])
# Out:
#         userId  movieId  rating   timestamp
# 261          3       31     0.5  1306463578
# 262          3      527     0.5  1306464275
# 263          3      647     0.5  1306463619
# 264          3      688     0.5  1306464228
# 265          3      720     0.5  1306463595
# ...        ...      ...     ...         ...
# 99394      608     6827     0.5  1117519648
# 99408      608     7004     0.5  1117506252
# 100345     610    61818     0.5  1493848943
# 100415     610    72424     0.5  1493849030
# 100797     610   145951     0.5  1493849019
#
# [1370 rows x 4 columns]

# %% [markdown]
# Задание 4
# 1 point possible (graded)
# Объедините датафреймы ratings и movies, используя параметр how='outer'.
# Сколько строк в получившемся датафрейме?

# %%
movies.drop_duplicates(subset = 'movieId', keep = 'first', inplace = True)
rating.drop_duplicates(subset = 'movieId', keep = 'first', inplace = True)
#display(movies.info())
#display(rating.info())
ratings_movies=rating.merge(movies, how = 'left', on = 'movieId')
display(ratings_movies.describe())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-dc734f64ea4e> in <module>
#       3 #display(movies.info())
#       4 #display(rating.info())
# ----> 5 ratings_movies=rating.merge(movies, how = 'left', on = 'movieId')
#       6 display(ratings_movies.describe())
#
# C:\Anaconda3\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    7332             copy=copy,
#    7333             indicator=indicator,
# -> 7334             validate=validate,
#    7335         )
#    7336
#
# C:\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      79         copy=copy,
#      80         indicator=indicator,
# ---> 81         validate=validate,
#      82     )
#      83     return op.get_result()
#
# C:\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     628         # validate the merge keys dtypes. We may need to coerce
#     629         # to avoid incompat dtypes
# --> 630         self._maybe_coerce_merge_keys()
#     631
#     632         # If argument passed to validate,
#
# C:\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _maybe_coerce_merge_keys(self)
#    1136                     inferred_right in string_types and inferred_left not in string_types
#    1137                 ):
# -> 1138                     raise ValueError(msg)
#    1139
#    1140             # datetimelikes must match exactly
#
# ValueError: You are trying to merge on int64 and object columns. If you wish to proceed you should use pd.concat

# %% [markdown]
# Задание 5
# 1 point possible (graded)
# Найдите в датафрейме movies фильм с movieId=3456.
# Какой у него год выпуска?
# P. S. Попробуйте найти movieId этого фильма в датафрейме ratings. Это будет ключом к ответу на следующее задание.

# %%
import pandas as pd
rating = pd.read_csv('rating.csv')
display(rating.loc[rating.movieId=='3456'])
display(movies.loc[movies.movieId==3456])
# Out:
# Empty DataFrame
# Columns: [userId, movieId, rating, timestamp]
# Index: []
# Empty DataFrame
# Columns: [movieId, title, genres]
# Index: []

# %%
import pandas as pd
rating = pd.read_csv('ratings.xls')
#rating.drop_duplicates(subset = 'movieId', keep = 'first', inplace = True)
movies = pd.read_csv('movies.xls')
#movies.drop_duplicates(subset = 'movieId', keep = 'first', inplace = True)
ratings_movies=movies.merge(rating, how = 'outer', on = 'movieId')
display(ratings_movies.info())
#display(rating.info())
#display(movies.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100854 entries, 0 to 100853
# Data columns (total 6 columns):
# movieId      100854 non-null int64
# title        100854 non-null object
# genres       100854 non-null object
# userId       100836 non-null float64
# rating       100836 non-null float64
# timestamp    100836 non-null float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 5.4+ MB
# None
